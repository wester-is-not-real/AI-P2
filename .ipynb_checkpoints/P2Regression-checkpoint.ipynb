# %%
import torch
import numpy as np
import pandas as pd
from torch.utils import data
from torch.utils.data import Dataset, TensorDataset, DataLoader
from torch import nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(url, names=column_names,
                          na_values='?', comment='\t',
                          sep=' ', skipinitialspace=True)

dataset = raw_dataset.copy()
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1

# %%
dataset.isna().sum()
dataset = dataset.dropna()

# Change location categories
dataset['Origin'] = dataset['Origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})
dataset = pd.get_dummies(dataset, columns=['Origin'], prefix='', prefix_sep='')
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan    USA
# 393          82   False  False   True
# 394          82    True  False  False
# 395          82   False  False   True
# 396          82   False  False   True
# 397          82   False  False   True

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)
print("shape of train_dataset: ", train_dataset.shape)
print("shape of test_dataset: ", test_dataset.shape)
# Out:
# shape of train_dataset:  (314, 10)
# shape of test_dataset:  (78, 10)

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('MPG')
test_labels = test_features.pop('MPG')
print("shape of train_features: ", train_features.shape)
print("shape of test_features: ", test_features.shape)
print("shape of train_labels: ", train_labels.shape)
print("shape of test_labels: ", test_labels.shape)
# Out:
# shape of train_features:  (314, 9)
# shape of test_features:  (78, 9)
# shape of train_labels:  (314,)
# shape of test_labels:  (78,)

# %%
batch = 10
X =np.array(train_features.values.astype(np.float32))
X = torch.Tensor(X)
print(X.shape)
y = np.array(train_labels.values.astype(np.float32))
y = torch.Tensor(y)
print("before reshape: ", y.shape)
y = torch.reshape(y, (-1,1))
print("after reshape: ", y.shape)

train = TensorDataset(X,y)
train_dataloader = DataLoader(train, batch_size=batch, shuffle=True)
sample = next(iter(train_dataloader))
print("sample batch: ", sample)
print("batch len: ", len(sample))

for X, y in train_dataloader:
    print(f"Shape of X [B, F]: {X.shape}")
    print(f"Shape of y [B, L]: {y.shape} {y.dtype}")
    break
# Out:
# torch.Size([314, 9])
# before reshape:  torch.Size([314])
# after reshape:  torch.Size([314, 1])
# sample batch:  [tensor([[4.0000e+00, 8.5000e+01, 6.5000e+01, 1.9750e+03, 1.9400e+01, 8.1000e+01,
#          0.0000e+00, 1.0000e+00, 0.0000e+00],
#         [4.0000e+00, 8.5000e+01, 6.5000e+01, 2.0200e+03, 1.9200e+01, 7.9000e+01,
#          0.0000e+00, 1.0000e+00, 0.0000e+00],
#         [4.0000e+00, 1.4000e+02, 7.2000e+01, 2.4010e+03, 1.9500e+01, 7.3000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [6.0000e+00, 1.5500e+02, 1.0700e+02, 2.4720e+03, 1.4000e+01, 7.3000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [8.0000e+00, 3.5000e+02, 1.2500e+02, 3.9000e+03, 1.7400e+01, 7.9000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [8.0000e+00, 3.0200e+02, 1.4000e+02, 4.6380e+03, 1.6000e+01, 7.4000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [8.0000e+00, 3.0200e+02, 1.2900e+02, 3.7250e+03, 1.3400e+01, 7.9000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [4.0000e+00, 1.0500e+02, 7.0000e+01, 2.2000e+03, 1.3200e+01, 7.9000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [4.0000e+00, 1.0800e+02, 9.3000e+01, 2.3910e+03, 1.5500e+01, 7.4000e+01,
#          0.0000e+00, 1.0000e+00, 0.0000e+00],
#         [8.0000e+00, 3.0500e+02, 1.4500e+02, 3.4250e+03, 1.3200e+01, 7.8000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00]]), tensor([[37.0000],
#         [31.8000],
#         [21.0000],
#         [21.0000],
#         [23.0000],
#         [14.0000],
#         [17.6000],
#         [34.2000],
#         [26.0000],
#         [19.2000]])]
# batch len:  2
# Shape of X [B, F]: torch.Size([10, 9])
# Shape of y [B, L]: torch.Size([10, 1]) torch.float32

# %%
X =np.array(test_features.values.astype(np.float32))
X = torch.Tensor(X)
y = np.array(test_labels.values.astype(np.float32))
y = torch.Tensor(y)
y = torch.reshape(y, (-1,1))
test = TensorDataset(X,y)
test_dataloader = DataLoader(test, batch_size=batch, shuffle=True)
sample = next(iter(test_dataloader))
print("sample batch: ", sample[0])
print("batch len: ", len(sample))

for X, y in test_dataloader:
    print(f"Shape of X [B, F]: {X.shape}")
    print(f"Shape of y [B, L]: {y.shape} {y.dtype}")
    break
# Out:
# sample batch:  tensor([[4.0000e+00, 9.8000e+01, 7.9000e+01, 2.2550e+03, 1.7700e+01, 7.6000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [4.0000e+00, 1.2000e+02, 7.9000e+01, 2.6250e+03, 1.8600e+01, 8.2000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [8.0000e+00, 3.0400e+02, 1.9300e+02, 4.7320e+03, 1.8500e+01, 7.0000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [8.0000e+00, 3.5100e+02, 1.5800e+02, 4.3630e+03, 1.3000e+01, 7.3000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [6.0000e+00, 2.2500e+02, 1.0000e+02, 3.6510e+03, 1.7700e+01, 7.6000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [8.0000e+00, 3.0200e+02, 1.3700e+02, 4.0420e+03, 1.4500e+01, 7.3000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [4.0000e+00, 7.8000e+01, 5.2000e+01, 1.9850e+03, 1.9400e+01, 7.8000e+01,
#          0.0000e+00, 1.0000e+00, 0.0000e+00],
#         [4.0000e+00, 1.5600e+02, 1.0500e+02, 2.8000e+03, 1.4400e+01, 8.0000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [8.0000e+00, 3.5100e+02, 1.3800e+02, 3.9550e+03, 1.3200e+01, 7.9000e+01,
#          0.0000e+00, 0.0000e+00, 1.0000e+00],
#         [4.0000e+00, 1.0500e+02, 7.4000e+01, 2.1900e+03, 1.4200e+01, 8.1000e+01,
#          1.0000e+00, 0.0000e+00, 0.0000e+00]])
# batch len:  2
# Shape of X [B, F]: torch.Size([10, 9])
# Shape of y [B, L]: torch.Size([10, 1]) torch.float32

# %%
class NNModel(nn.Module):
    def __init__(self):
        #super(NNModel, self).__init__()
        super().__init__()
        self.norm = nn.BatchNorm1d(9)
        self.fc1 = nn.Linear(9,1)


    def forward(self, x):
        t = self.norm(x)
        t = self.fc1(t)
        return t
    
class NNModel2(nn.Module):
    def __init__(self):
        #super(NNModel, self).__init__()
        super().__init__()
        self.norm = nn.BatchNorm1d(9)
        self.fc1 = nn.Linear(9,10)
        self.fc2 = nn.Linear(10,20)
        self.fc3 = nn.Linear(20,10)
        self.fc4 = nn.Linear(10,1)
        self.relu = nn.ReLU()


    def forward(self, x):
        t = self.norm(x)
        t = self.fc1(t)
        t = self.relu(t)
        t = self.fc2(t)
        t = self.relu(t)
        t = self.fc3(t)
        t = self.relu(t)
        t = self.fc4(t)
        return t
    
class NNModel3(nn.Module):
    def __init__(self):
        #super(NNModel, self).__init__()
        super().__init__()
        self.norm = nn.BatchNorm1d(9)
        self.fc1 = nn.Linear(9,10)
        self.fc2 = nn.Linear(10,20)
        self.fc3 = nn.Linear(20,30)
        self.fc4 = nn.Linear(30,20)
        self.fc5 = nn.Linear(20,1)
        self.relu = nn.ReLU()


    def forward(self, x):
        t = self.norm(x)
        t = self.fc1(t)
        t = self.relu(t)
        t = self.fc2(t)
        t = self.relu(t)
        t = self.fc3(t)
        t = self.relu(t)
        t = self.fc4(t)
        t = self.relu(t)
        t = self.fc5(t)
        return t

# %%
nnet1 = NNModel()
nnet2 = NNModel2()
nnet3 = NNModel3()

criterion = nn.MSELoss()
optimizer1 = optim.Adam(nnet1.parameters(), lr=0.01)
optimizer2 = optim.Adam(nnet2.parameters(), lr=0.01)
optimizer3 = optim.Adam(nnet3.parameters(), lr=0.01)

# from torchinfo import summary
# batch = 10
# summary(nnet1, input_size=(batch, 9), device='cpu', col_names=['input_size', 'output_size',
#                                                               'num_params'])

# %%
def train(dataloader, model, loss_fn, optimizer, device,train_losses):
    train_loss = 0
    size = len(dataloader.dataset)
    # print("size: ", size)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        #print("X: " , X)
        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        train_loss += loss.item()

        if batch % 10 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"Train loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    train_loss = train_loss/size
    train_losses.append(train_loss)

def test(dataloader, model, loss_fn, device):
    size = len(dataloader.dataset)
    # print("size: ", size)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
    
    mse = test_loss / size
    test_loss /= num_batches
    accuracy = 100-mse
    #correct /= size
    print(f"Test Error: \n Accuracy: {accuracy:4f}%, Avg loss: {test_loss:>8f} \n")

# %%
device = 'cpu'
device = mps_device
epochs = 20

train_losses = []
# Train NN1
nnet1 = nnet1.to(device=device)
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, nnet1, criterion, optimizer1, device,train_losses)
    test(test_dataloader, nnet1, criterion, device)
print("Done!")


# Plot losses
plt.title('Training Loss')
plt.plot(train_losses, label='Training')
#plt.plot(test_losses, label='Validation')
#print("Mean validation loss: {:4f}".format(sum(val_losses)/len(val_losses)))
plt.legend()
plt.show()
# Out:
# Epoch 1
# -------------------------------
# Train loss: 992.238464  [   10/  314]
# Train loss: 687.188477  [  110/  314]
# Train loss: 615.907471  [  210/  314]
# Train loss: 360.432068  [  310/  314]
# Test Error:
#  Accuracy: 39.633995%, Avg loss: 588.568550
#
# Epoch 2
# -------------------------------
# Train loss: 535.987305  [   10/  314]
# Train loss: 399.206940  [  110/  314]
# Train loss: 365.494476  [  210/  314]
# Train loss: 444.850311  [  310/  314]
# Test Error:
#  Accuracy: 46.201465%, Avg loss: 524.535721
#
# Epoch 3
# -------------------------------
# Train loss: 406.795013  [   10/  314]
# Train loss: 442.800201  [  110/  314]
# Train loss: 318.239014  [  210/  314]
# Train loss: 378.678436  [  310/  314]
# Test Error:
#  Accuracy: 54.712952%, Avg loss: 441.548717
#
# Epoch 4
# -------------------------------
# Train loss: 390.474854  [   10/  314]
# Train loss: 533.955017  [  110/  314]
# Train loss: 473.340820  [  210/  314]
# Train loss: 457.732330  [  310/  314]
# Test Error:
#  Accuracy: 58.248756%, Avg loss: 407.074627
#
# Epoch 5
# -------------------------------
# Train loss: 453.210266  [   10/  314]
# Train loss: 321.692383  [  110/  314]
# Train loss: 398.164642  [  210/  314]
# Train loss: 288.914215  [  310/  314]
# Test Error:
#  Accuracy: 68.619987%, Avg loss: 305.955124
#
# Epoch 6
# -------------------------------
# Train loss: 189.564926  [   10/  314]
# Train loss: 269.776855  [  110/  314]
# Train loss: 180.088303  [  210/  314]
# Train loss: 161.549118  [  310/  314]
# Test Error:
#  Accuracy: 76.780166%, Avg loss: 226.393383
#
# Epoch 7
# -------------------------------
# Train loss: 103.793312  [   10/  314]
# Train loss: 354.789001  [  110/  314]
# Train loss: 147.223175  [  210/  314]
# Train loss: 94.869621  [  310/  314]
# Test Error:
#  Accuracy: 81.587804%, Avg loss: 179.518911
#
# Epoch 8
# -------------------------------
# Train loss: 267.956696  [   10/  314]
# Train loss: 229.260727  [  110/  314]
# Train loss: 83.907852  [  210/  314]
# Train loss: 29.471210  [  310/  314]
# Test Error:
#  Accuracy: 87.929627%, Avg loss: 117.686136
#
# Epoch 9
# -------------------------------
# Train loss: 152.292374  [   10/  314]
# Train loss: 62.704617  [  110/  314]
# Train loss: 100.383293  [  210/  314]
# Train loss: 61.233990  [  310/  314]
# Test Error:
#  Accuracy: 92.838739%, Avg loss: 69.822297
#
# Epoch 10
# -------------------------------
# Train loss: 56.794048  [   10/  314]
# Train loss: 35.932503  [  110/  314]
# Train loss: 68.168289  [  210/  314]
# Train loss: 52.720062  [  310/  314]
# Test Error:
#  Accuracy: 95.020015%, Avg loss: 48.554852
#
# Epoch 11
# -------------------------------
# Train loss: 82.835426  [   10/  314]
# Train loss: 95.629829  [  110/  314]
# Train loss: 19.274548  [  210/  314]
# Train loss: 49.346737  [  310/  314]
# Test Error:
#  Accuracy: 96.730113%, Avg loss: 31.881401
#
# Epoch 12
# -------------------------------
# Train loss: 29.003895  [   10/  314]
# Train loss: 19.099277  [  110/  314]
# Train loss: 52.985165  [  210/  314]
# Train loss: 26.622793  [  310/  314]
# Test Error:
#  Accuracy: 97.390202%, Avg loss: 25.445530
#
# Epoch 13
# -------------------------------
# Train loss: 27.745691  [   10/  314]
# Train loss: 79.005470  [  110/  314]
# Train loss: 16.213169  [  210/  314]
# Train loss: 31.911926  [  310/  314]
# Test Error:
#  Accuracy: 97.834924%, Avg loss: 21.109488
#
# Epoch 14
# -------------------------------
# Train loss: 24.740025  [   10/  314]
# Train loss: 16.177546  [  110/  314]
# Train loss: 18.164602  [  210/  314]
# Train loss: 28.234974  [  310/  314]
# Test Error:
#  Accuracy: 98.290387%, Avg loss: 16.668728
#
# Epoch 15
# -------------------------------
# Train loss: 14.871982  [   10/  314]
# Train loss: 18.452620  [  110/  314]
# Train loss: 38.433380  [  210/  314]
# Train loss: 53.552845  [  310/  314]
# Test Error:
#  Accuracy: 98.310684%, Avg loss: 16.470834
#
# Epoch 16
# -------------------------------
# Train loss: 22.584898  [   10/  314]
# Train loss: 15.678731  [  110/  314]
# Train loss: 15.894650  [  210/  314]
# Train loss: 7.549905  [  310/  314]
# Test Error:
#  Accuracy: 98.440644%, Avg loss: 15.203719
#
# Epoch 17
# -------------------------------
# Train loss: 23.233820  [   10/  314]
# Train loss: 8.300921  [  110/  314]
# Train loss: 22.183084  [  210/  314]
# Train loss: 27.923340  [  310/  314]
# Test Error:
#  Accuracy: 98.531329%, Avg loss: 14.319539
#
# Epoch 18
# -------------------------------
# Train loss: 20.661476  [   10/  314]
# Train loss: 20.631126  [  110/  314]
# Train loss: 17.485350  [  210/  314]
# Train loss: 12.009768  [  310/  314]
# Test Error:
#  Accuracy: 98.640507%, Avg loss: 13.255058
#
# Epoch 19
# -------------------------------
# Train loss: 23.911047  [   10/  314]
# Train loss: 3.439365  [  110/  314]
# Train loss: 22.864780  [  210/  314]
# Train loss: 14.165799  [  310/  314]
# Test Error:
#  Accuracy: 98.539697%, Avg loss: 14.237950
#
# Epoch 20
# -------------------------------
# Train loss: 27.787323  [   10/  314]
# Train loss: 28.288391  [  110/  314]
# Train loss: 18.936722  [  210/  314]
# Train loss: 30.030710  [  310/  314]
# Test Error:
#  Accuracy: 98.460883%, Avg loss: 15.006393
#
# Done!

# %%
# Train NN2
train_losses = []
nnet2 = nnet2.to(device=device)
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, nnet2, criterion, optimizer2, device,train_losses)
    test(test_dataloader, nnet2, criterion, device)
print("Done!")


# Plot losses
plt.title('Training Loss')
plt.plot(train_losses, label='Training')
#plt.plot(test_losses, label='Validation')
#print("Mean validation loss: {:4f}".format(sum(val_losses)/len(val_losses)))
plt.legend()
plt.show()
# Out:
# Epoch 1
# -------------------------------
# Train loss: 772.213867  [   10/  314]
# Train loss: 596.072815  [  110/  314]
# Train loss: 477.768890  [  210/  314]
# Train loss: 154.038437  [  310/  314]
# Test Error:
#  Accuracy: 89.627611%, Avg loss: 101.130790
#
# Epoch 2
# -------------------------------
# Train loss: 111.738579  [   10/  314]
# Train loss: 48.272659  [  110/  314]
# Train loss: 29.845261  [  210/  314]
# Train loss: 10.868072  [  310/  314]
# Test Error:
#  Accuracy: 97.965040%, Avg loss: 19.840861
#
# Epoch 3
# -------------------------------
# Train loss: 38.776348  [   10/  314]
# Train loss: 70.048409  [  110/  314]
# Train loss: 40.157280  [  210/  314]
# Train loss: 14.218689  [  310/  314]
# Test Error:
#  Accuracy: 98.843667%, Avg loss: 11.274246
#
# Epoch 4
# -------------------------------
# Train loss: 16.216028  [   10/  314]
# Train loss: 26.516642  [  110/  314]
# Train loss: 47.195511  [  210/  314]
# Train loss: 8.100286  [  310/  314]
# Test Error:
#  Accuracy: 98.125402%, Avg loss: 18.277335
#
# Epoch 5
# -------------------------------
# Train loss: 37.906219  [   10/  314]
# Train loss: 36.620827  [  110/  314]
# Train loss: 20.008146  [  210/  314]
# Train loss: 4.093369  [  310/  314]
# Test Error:
#  Accuracy: 98.953426%, Avg loss: 10.204094
#
# Epoch 6
# -------------------------------
# Train loss: 7.151692  [   10/  314]
# Train loss: 14.287903  [  110/  314]
# Train loss: 13.821907  [  210/  314]
# Train loss: 30.844782  [  310/  314]
# Test Error:
#  Accuracy: 98.598427%, Avg loss: 13.665340
#
# Epoch 7
# -------------------------------
# Train loss: 3.665222  [   10/  314]
# Train loss: 17.625248  [  110/  314]
# Train loss: 5.192319  [  210/  314]
# Train loss: 27.283304  [  310/  314]
# Test Error:
#  Accuracy: 99.071816%, Avg loss: 9.049794
#
# Epoch 8
# -------------------------------
# Train loss: 58.331543  [   10/  314]
# Train loss: 34.046547  [  110/  314]
# Train loss: 5.598667  [  210/  314]
# Train loss: 15.471370  [  310/  314]
# Test Error:
#  Accuracy: 99.170292%, Avg loss: 8.089652
#
# Epoch 9
# -------------------------------
# Train loss: 24.932592  [   10/  314]
# Train loss: 43.619991  [  110/  314]
# Train loss: 41.340389  [  210/  314]
# Train loss: 13.392489  [  310/  314]
# Test Error:
#  Accuracy: 98.519671%, Avg loss: 14.433208
#
# Epoch 10
# -------------------------------
# Train loss: 23.235266  [   10/  314]
# Train loss: 35.929974  [  110/  314]
# Train loss: 16.655634  [  210/  314]
# Train loss: 8.868352  [  310/  314]
# Test Error:
#  Accuracy: 99.160915%, Avg loss: 8.181077
#
# Epoch 11
# -------------------------------
# Train loss: 8.593659  [   10/  314]
# Train loss: 4.957495  [  110/  314]
# Train loss: 21.733362  [  210/  314]
# Train loss: 16.378233  [  310/  314]
# Test Error:
#  Accuracy: 99.175427%, Avg loss: 8.039590
#
# Epoch 12
# -------------------------------
# Train loss: 5.415420  [   10/  314]
# Train loss: 10.290324  [  110/  314]
# Train loss: 3.855752  [  210/  314]
# Train loss: 5.150724  [  310/  314]
# Test Error:
#  Accuracy: 99.159555%, Avg loss: 8.194341
#
# Epoch 13
# -------------------------------
# Train loss: 17.661863  [   10/  314]
# Train loss: 23.169353  [  110/  314]
# Train loss: 5.059949  [  210/  314]
# Train loss: 7.051437  [  310/  314]
# Test Error:
#  Accuracy: 98.699768%, Avg loss: 12.677259
#
# Epoch 14
# -------------------------------
# Train loss: 7.101105  [   10/  314]
# Train loss: 6.926983  [  110/  314]
# Train loss: 6.035452  [  210/  314]
# Train loss: 10.704428  [  310/  314]
# Test Error:
#  Accuracy: 98.237837%, Avg loss: 17.181093
#
# Epoch 15
# -------------------------------
# Train loss: 6.890468  [   10/  314]
# Train loss: 39.819881  [  110/  314]
# Train loss: 13.215166  [  210/  314]
# Train loss: 33.138691  [  310/  314]
# Test Error:
#  Accuracy: 99.323384%, Avg loss: 6.597003
#
# Epoch 16
# -------------------------------
# Train loss: 21.535776  [   10/  314]
# Train loss: 11.226710  [  110/  314]
# Train loss: 53.779339  [  210/  314]
# Train loss: 39.125973  [  310/  314]
# Test Error:
#  Accuracy: 99.178357%, Avg loss: 8.011020
#
# Epoch 17
# -------------------------------
# Train loss: 6.157738  [   10/  314]
# Train loss: 7.300809  [  110/  314]
# Train loss: 4.048561  [  210/  314]
# Train loss: 11.436069  [  310/  314]
# Test Error:
#  Accuracy: 98.881119%, Avg loss: 10.909092
#
# Epoch 18
# -------------------------------
# Train loss: 16.681074  [   10/  314]
# Train loss: 28.097136  [  110/  314]
# Train loss: 19.682806  [  210/  314]
# Train loss: 10.979529  [  310/  314]
# Test Error:
#  Accuracy: 99.110433%, Avg loss: 8.673282
#
# Epoch 19
# -------------------------------
# Train loss: 29.022144  [   10/  314]
# Train loss: 9.484603  [  110/  314]
# Train loss: 8.797873  [  210/  314]
# Train loss: 4.246341  [  310/  314]
# Test Error:
#  Accuracy: 99.139383%, Avg loss: 8.391012
#
# Epoch 20
# -------------------------------
# Train loss: 31.767609  [   10/  314]
# Train loss: 10.513884  [  110/  314]
# Train loss: 13.453923  [  210/  314]
# Train loss: 25.678061  [  310/  314]
# Test Error:
#  Accuracy: 99.151308%, Avg loss: 8.274748
#
# Done!

# %%
# Train NN3
train_losses = []
nnet3 = nnet3.to(device=device)
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, nnet3, criterion, optimizer3, device,train_losses)
    test(test_dataloader, nnet3, criterion, device)
print("Done!")



# Plot losses
plt.title('Training Loss')
plt.plot(train_losses, label='Training')
#plt.plot(test_losses, label='Validation')
#print("Mean validation loss: {:4f}".format(sum(val_losses)/len(val_losses)))
plt.legend()
plt.show()
# Out:
# Epoch 1
# -------------------------------
# Train loss: 744.650696  [   10/  314]
# Train loss: 427.082123  [  110/  314]
# Train loss: 454.008606  [  210/  314]
# Train loss: 141.785812  [  310/  314]
# Test Error:
#  Accuracy: 92.297223%, Avg loss: 75.102071
#
# Epoch 2
# -------------------------------
# Train loss: 164.390747  [   10/  314]
# Train loss: 30.127768  [  110/  314]
# Train loss: 31.509171  [  210/  314]
# Train loss: 29.466867  [  310/  314]
# Test Error:
#  Accuracy: 98.987831%, Avg loss: 9.868652
#
# Epoch 3
# -------------------------------
# Train loss: 8.586782  [   10/  314]
# Train loss: 10.750348  [  110/  314]
# Train loss: 27.825663  [  210/  314]
# Train loss: 5.767444  [  310/  314]
# Test Error:
#  Accuracy: 99.046444%, Avg loss: 9.297168
#
# Epoch 4
# -------------------------------
# Train loss: 10.027369  [   10/  314]
# Train loss: 22.104002  [  110/  314]
# Train loss: 12.473156  [  210/  314]
# Train loss: 6.242519  [  310/  314]
# Test Error:
#  Accuracy: 99.138350%, Avg loss: 8.401090
#
# Epoch 5
# -------------------------------
# Train loss: 10.379491  [   10/  314]
# Train loss: 14.655425  [  110/  314]
# Train loss: 16.897957  [  210/  314]
# Train loss: 9.943493  [  310/  314]
# Test Error:
#  Accuracy: 99.046581%, Avg loss: 9.295838
#
# Epoch 6
# -------------------------------
# Train loss: 18.315945  [   10/  314]
# Train loss: 46.116596  [  110/  314]
# Train loss: 6.216041  [  210/  314]
# Train loss: 11.122745  [  310/  314]
# Test Error:
#  Accuracy: 99.118856%, Avg loss: 8.591153
#
# Epoch 7
# -------------------------------
# Train loss: 41.570965  [   10/  314]
# Train loss: 24.041075  [  110/  314]
# Train loss: 12.979810  [  210/  314]
# Train loss: 9.469757  [  310/  314]
# Test Error:
#  Accuracy: 99.034297%, Avg loss: 9.415603
#
# Epoch 8
# -------------------------------
# Train loss: 13.501490  [   10/  314]
# Train loss: 14.617345  [  110/  314]
# Train loss: 8.290474  [  210/  314]
# Train loss: 8.034119  [  310/  314]
# Test Error:
#  Accuracy: 98.746535%, Avg loss: 12.221283
#
# Epoch 9
# -------------------------------
# Train loss: 32.233410  [   10/  314]
# Train loss: 15.532471  [  110/  314]
# Train loss: 2.477713  [  210/  314]
# Train loss: 5.187995  [  310/  314]
# Test Error:
#  Accuracy: 97.737055%, Avg loss: 22.063709
#
# Epoch 10
# -------------------------------
# Train loss: 34.075325  [   10/  314]
# Train loss: 69.698433  [  110/  314]
# Train loss: 33.889019  [  210/  314]
# Train loss: 22.653173  [  310/  314]
# Test Error:
#  Accuracy: 98.328473%, Avg loss: 16.297392
#
# Epoch 11
# -------------------------------
# Train loss: 11.385524  [   10/  314]
# Train loss: 45.526047  [  110/  314]
# Train loss: 10.790366  [  210/  314]
# Train loss: 11.630610  [  310/  314]
# Test Error:
#  Accuracy: 98.312395%, Avg loss: 16.454148
#
# Epoch 12
# -------------------------------
# Train loss: 21.742222  [   10/  314]
# Train loss: 38.302914  [  110/  314]
# Train loss: 25.911331  [  210/  314]
# Train loss: 28.649000  [  310/  314]
# Test Error:
#  Accuracy: 98.043488%, Avg loss: 19.075993
#
# Epoch 13
# -------------------------------
# Train loss: 19.196817  [   10/  314]
# Train loss: 13.157227  [  110/  314]
# Train loss: 6.160558  [  210/  314]
# Train loss: 22.388142  [  310/  314]
# Test Error:
#  Accuracy: 98.172322%, Avg loss: 17.819864
#
# Epoch 14
# -------------------------------
# Train loss: 8.690307  [   10/  314]
# Train loss: 25.394789  [  110/  314]
# Train loss: 8.163859  [  210/  314]
# Train loss: 15.832148  [  310/  314]
# Test Error:
#  Accuracy: 98.276483%, Avg loss: 16.804295
#
# Epoch 15
# -------------------------------
# Train loss: 27.637800  [   10/  314]
# Train loss: 6.946394  [  110/  314]
# Train loss: 17.303911  [  210/  314]
# Train loss: 29.208475  [  310/  314]
# Test Error:
#  Accuracy: 98.800594%, Avg loss: 11.694212
#
# Epoch 16
# -------------------------------
# Train loss: 13.558780  [   10/  314]
# Train loss: 12.370772  [  110/  314]
# Train loss: 10.842664  [  210/  314]
# Train loss: 10.390869  [  310/  314]
# Test Error:
#  Accuracy: 98.932846%, Avg loss: 10.404753
#
# Epoch 17
# -------------------------------
# Train loss: 6.240952  [   10/  314]
# Train loss: 12.880778  [  110/  314]
# Train loss: 11.021220  [  210/  314]
# Train loss: 10.600139  [  310/  314]
# Test Error:
#  Accuracy: 99.061542%, Avg loss: 9.149967
#
# Epoch 18
# -------------------------------
# Train loss: 9.976648  [   10/  314]
# Train loss: 8.642265  [  110/  314]
# Train loss: 8.904002  [  210/  314]
# Train loss: 9.994459  [  310/  314]
# Test Error:
#  Accuracy: 98.700046%, Avg loss: 12.674550
#
# Epoch 19
# -------------------------------
# Train loss: 22.419546  [   10/  314]
# Train loss: 10.364163  [  110/  314]
# Train loss: 7.026865  [  210/  314]
# Train loss: 5.852418  [  310/  314]
# Test Error:
#  Accuracy: 98.703306%, Avg loss: 12.642764
#
# Epoch 20
# -------------------------------
# Train loss: 11.327129  [   10/  314]
# Train loss: 16.881739  [  110/  314]
# Train loss: 4.765579  [  210/  314]
# Train loss: 5.585746  [  310/  314]
# Test Error:
#  Accuracy: 98.314205%, Avg loss: 16.436503
#
# Done!
